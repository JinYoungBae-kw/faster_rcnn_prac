# %% [markdown]
# ### MMDetection 설치

# %% [markdown]
# #### pytorch, torchvision 다운그레이드

# %%
# pytorch 임포트
import torch
print(torch.__version__)
# Out:
# 2.5.1+cu124

# %%
# pytorch 다운그레이드
# !pip install torch==2.0.0 torchvision==0.15.1  --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Collecting torch==2.0.0
#   Downloading https://download.pytorch.org/whl/cu118/torch-2.0.0%2Bcu118-cp311-cp311-linux_x86_64.whl (2267.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB 474.6 kB/s eta 0:00:00
# Collecting torchvision==0.15.1
#   Downloading https://download.pytorch.org/whl/cu118/torchvision-0.15.1%2Bcu118-cp311-cp311-linux_x86_64.whl (6.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 75.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.0.0) (3.17.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch==2.0.0) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch==2.0.0) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.0.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.0) (3.1.5)
# Collecting triton==2.0.0 (from torch==2.0.0)
#   Downloading https://download.pytorch.org/whl/triton-2.0.0-1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision==0.15.1) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torchvision==0.15.1) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision==0.15.1) (11.1.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch==2.0.0) (3.31.4)
# Collecting lit (from triton==2.0.0->torch==2.0.0)
#   Downloading https://download.pytorch.org/whl/lit-15.0.7.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 kB 14.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.0.0) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.1) (2025.1.31)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch==2.0.0) (1.3.0)
# Building wheels for collected packages: lit
#   Building wheel for lit (setup.py) ... done
#   Created wheel for lit: filename=lit-15.0.7-py3-none-any.whl size=89991 sha256=6da77da3a4a90ea385f5617ab180c85e6a16a99faad6ba1f61023357a5cfd81a
#   Stored in directory: /root/.cache/pip/wheels/fc/5d/45/34fe9945d5e45e261134e72284395be36c2d4828af38e2b0fe
# Successfully built lit
# Installing collected packages: lit, triton, torch, torchvision
#   Attempting uninstall: triton
#     Found existing installation: triton 3.1.0
#     Uninstalling triton-3.1.0:
#       Successfully uninstalled triton-3.1.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.1+cu124
#     Uninstalling torch-2.5.1+cu124:
#       Successfully uninstalled torch-2.5.1+cu124
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.20.1+cu124
#     Uninstalling torchvision-0.20.1+cu124:
#       Successfully uninstalled torchvision-0.20.1+cu124
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.5.1+cu124 requires torch==2.5.1, but you have torch 2.0.0+cu118 which is incompatible.
# Successfully installed lit-15.0.7 torch-2.0.0+cu118 torchvision-0.15.1+cu118 triton-2.0.0

# %% [markdown]
# #### mmcv-full 및 mmdetection 설치

# %%
# mmcv를 위해서 mmcv-full을 먼저 설치
# !pip install mmcv-full -f https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/index.html

# 실습 코드는 mmdetection 2.x 기준
# 따라서 mmdetection 2.x branch의 소스코드 기반으로 mmdetection 설치 필요.
# !git clone --branch 2.x https://github.com/open-mmlab/mmdetection.git
# !cd mmdetection; python setup.py install
# Out:
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/index.html
# Collecting mmcv-full
#   Downloading https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/mmcv_full-1.7.2-cp311-cp311-manylinux1_x86_64.whl (70.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 MB 10.7 MB/s eta 0:00:00
# Collecting addict (from mmcv-full)
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mmcv-full) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from mmcv-full) (24.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from mmcv-full) (11.1.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from mmcv-full) (6.0.2)
# Collecting yapf (from mmcv-full)
#   Downloading yapf-0.43.0-py3-none-any.whl.metadata (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.11/dist-packages (from mmcv-full) (4.11.0.86)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.11/dist-packages (from yapf->mmcv-full) (4.3.6)
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Downloading yapf-0.43.0-py3-none-any.whl (256 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 24.8 MB/s eta 0:00:00
# Installing collected packages: addict, yapf, mmcv-full
# Successfully installed addict-2.4.0 mmcv-full-1.7.2 yapf-0.43.0
# Cloning into 'mmdetection'...
# remote: Enumerating objects: 38023, done.
# remote: Total 38023 (delta 0), reused 0 (delta 0), pack-reused 38023 (from 1)
# Receiving objects: 100% (38023/38023), 63.18 MiB | 11.83 MiB/s, done.
# Resolving deltas: 100% (26233/26233), done.
# running install
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# creating mmdet.egg-info
# writing mmdet.egg-info/PKG-INFO
# writing dependency_links to mmdet.egg-info/dependency_links.txt
# writing requirements to mmdet.egg-info/requires.txt
# writing top-level names to mmdet.egg-info/top_level.txt
# writing manifest file 'mmdet.egg-info/SOURCES.txt'
# reading manifest file 'mmdet.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching 'mmdet/VERSION'
# warning: no files found matching 'mmdet/.mim/model-index.yml'
# warning: no files found matching 'mmdet/.mim/demo/*/*'
# warning: no files found matching '*.py' under directory 'mmdet/.mim/configs'
# warning: no files found matching '*.yml' under directory 'mmdet/.mim/configs'
# warning: no files found matching '*.sh' under directory 'mmdet/.mim/tools'
# warning: no files found matching '*.py' under directory 'mmdet/.mim/tools'
# adding license file 'LICENSE'
# writing manifest file 'mmdet.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/lib/mmdet
# copying mmdet/version.py -> build/lib/mmdet
# copying mmdet/__init__.py -> build/lib/mmdet
# creating build/lib/mmdet/models
# copying mmdet/models/builder.py -> build/lib/mmdet/models
# copying mmdet/models/__init__.py -> build/lib/mmdet/models
# creating build/lib/mmdet/utils
# copying mmdet/utils/replace_cfg_vals.py -> build/lib/mmdet/utils
# copying mmdet/utils/compat_config.py -> build/lib/mmdet/utils
# copying mmdet/utils/util_distribution.py -> build/lib/mmdet/utils
# copying mmdet/utils/profiling.py -> build/lib/mmdet/utils
# copying mmdet/utils/misc.py -> build/lib/mmdet/utils
# copying mmdet/utils/collect_env.py -> build/lib/mmdet/utils
# copying mmdet/utils/setup_env.py -> build/lib/mmdet/utils
# copying mmdet/utils/util_random.py -> build/lib/mmdet/utils
# copying mmdet/utils/util_mixins.py -> build/lib/mmdet/utils
# copying mmdet/utils/rfnext.py -> build/lib/mmdet/utils
# copying mmdet/utils/ascend_util.py -> build/lib/mmdet/utils
# copying mmdet/utils/memory.py -> build/lib/mmdet/utils
# copying mmdet/utils/logger.py -> build/lib/mmdet/utils
# copying mmdet/utils/split_batch.py -> build/lib/mmdet/utils
# copying mmdet/utils/__init__.py -> build/lib/mmdet/utils
# copying mmdet/utils/contextmanagers.py -> build/lib/mmdet/utils
# creating build/lib/mmdet/datasets
# copying mmdet/datasets/deepfashion.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/xml_style.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/voc.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/custom.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/cityscapes.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/utils.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/dataset_wrappers.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/lvis.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/objects365.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/coco_panoptic.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/builder.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/wider_face.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/openimages.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/coco.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/__init__.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/coco_occluded.py -> build/lib/mmdet/datasets
# creating build/lib/mmdet/core
# copying mmdet/core/__init__.py -> build/lib/mmdet/core
# creating build/lib/mmdet/apis
# copying mmdet/apis/test.py -> build/lib/mmdet/apis
# copying mmdet/apis/train.py -> build/lib/mmdet/apis
# copying mmdet/apis/inference.py -> build/lib/mmdet/apis
# copying mmdet/apis/__init__.py -> build/lib/mmdet/apis
# creating build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/res2net.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/swin.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/hrnet.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/efficientnet.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/trident_resnet.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/detectors_resnet.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/hourglass.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/resnext.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/resnet.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/resnest.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/detectors_resnext.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/pvt.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/mobilenet_v2.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/regnet.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/darknet.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/__init__.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/csp_darknet.py -> build/lib/mmdet/models/backbones
# copying mmdet/models/backbones/ssd_vgg.py -> build/lib/mmdet/models/backbones
# creating build/lib/mmdet/models/plugins
# copying mmdet/models/plugins/pixel_decoder.py -> build/lib/mmdet/models/plugins
# copying mmdet/models/plugins/msdeformattn_pixel_decoder.py -> build/lib/mmdet/models/plugins
# copying mmdet/models/plugins/dropblock.py -> build/lib/mmdet/models/plugins
# copying mmdet/models/plugins/__init__.py -> build/lib/mmdet/models/plugins
# creating build/lib/mmdet/models/seg_heads
# copying mmdet/models/seg_heads/base_semantic_head.py -> build/lib/mmdet/models/seg_heads
# copying mmdet/models/seg_heads/panoptic_fpn_head.py -> build/lib/mmdet/models/seg_heads
# copying mmdet/models/seg_heads/__init__.py -> build/lib/mmdet/models/seg_heads
# creating build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/mask2former_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/embedding_rpn_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/ddod_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/base_dense_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/base_mask_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/corner_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/ga_rpn_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/atss_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/anchor_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/centernet_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/cascade_rpn_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/ga_retina_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/fsaf_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/pisa_ssd_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/yolox_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/nasfcos_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/dense_test_mixins.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/yolact_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/solo_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/autoassign_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/fovea_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/guided_anchor_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/ascend_ssd_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/gfl_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/yolo_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/tood_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/retina_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/ascend_anchor_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/solov2_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/sabl_retina_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/ssd_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/anchor_free_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/vfnet_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/fcos_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/reppoints_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/deformable_detr_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/free_anchor_retina_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/centripetal_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/ascend_retina_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/detr_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/retina_sepbn_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/__init__.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/rpn_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/maskformer_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/lad_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/ld_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/pisa_retinanet_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/paa_head.py -> build/lib/mmdet/models/dense_heads
# copying mmdet/models/dense_heads/yolof_head.py -> build/lib/mmdet/models/dense_heads
# creating build/lib/mmdet/models/utils
# copying mmdet/models/utils/positional_encoding.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/normed_predictor.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/panoptic_gt_processing.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/point_sample.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/se_layer.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/transformer.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/misc.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/csp_layer.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/gaussian_target.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/res_layer.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/conv_upsample.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/inverted_residual.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/ckpt_convert.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/builder.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/brick_wrappers.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/make_divisible.py -> build/lib/mmdet/models/utils
# copying mmdet/models/utils/__init__.py -> build/lib/mmdet/models/utils
# creating build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/yolox.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/kd_one_stage.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/retinanet.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/autoassign.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/mask_rcnn.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/scnet.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/trident_faster_rcnn.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/htc.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/cascade_rcnn.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/gfl.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/reppoints_detector.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/vfnet.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/fast_rcnn.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/mask_scoring_rcnn.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/tood.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/rpn.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/lad.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/atss.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/single_stage_instance_seg.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/base.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/maskformer.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/faster_rcnn.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/point_rend.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/fovea.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/panoptic_two_stage_segmentor.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/yolof.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/deformable_detr.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/cornernet.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/sparse_rcnn.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/two_stage.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/ddod.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/yolo.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/detr.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/fcos.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/solov2.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/fsaf.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/queryinst.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/single_stage.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/panoptic_fpn.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/__init__.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/solo.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/paa.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/mask2former.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/centernet.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/grid_rcnn.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/nasfcos.py -> build/lib/mmdet/models/detectors
# copying mmdet/models/detectors/yolact.py -> build/lib/mmdet/models/detectors
# creating build/lib/mmdet/models/necks
# copying mmdet/models/necks/rfp.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/fpg.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/nas_fpn.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/ssd_neck.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/dilated_encoder.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/nasfcos_fpn.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/fpn_carafe.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/dyhead.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/bfp.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/fpn.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/yolox_pafpn.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/hrfpn.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/channel_mapper.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/pafpn.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/__init__.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/ct_resnet_neck.py -> build/lib/mmdet/models/necks
# copying mmdet/models/necks/yolo_neck.py -> build/lib/mmdet/models/necks
# creating build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/dynamic_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/grid_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/trident_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/base_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/cascade_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/pisa_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/scnet_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/mask_scoring_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/htc_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/standard_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/test_mixins.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/sparse_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/__init__.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/double_roi_head.py -> build/lib/mmdet/models/roi_heads
# copying mmdet/models/roi_heads/point_rend_roi_head.py -> build/lib/mmdet/models/roi_heads
# creating build/lib/mmdet/models/losses
# copying mmdet/models/losses/varifocal_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/iou_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/ae_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/utils.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/seesaw_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/accuracy.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/focal_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/pisa_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/gfocal_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/ghm_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/cross_entropy_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/gaussian_focal_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/mse_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/smooth_l1_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/dice_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/kd_loss.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/__init__.py -> build/lib/mmdet/models/losses
# copying mmdet/models/losses/balanced_l1_loss.py -> build/lib/mmdet/models/losses
# creating build/lib/mmdet/models/seg_heads/panoptic_fusion_heads
# copying mmdet/models/seg_heads/panoptic_fusion_heads/heuristic_fusion_head.py -> build/lib/mmdet/models/seg_heads/panoptic_fusion_heads
# copying mmdet/models/seg_heads/panoptic_fusion_heads/maskformer_fusion_head.py -> build/lib/mmdet/models/seg_heads/panoptic_fusion_heads
# copying mmdet/models/seg_heads/panoptic_fusion_heads/base_panoptic_fusion_head.py -> build/lib/mmdet/models/seg_heads/panoptic_fusion_heads
# copying mmdet/models/seg_heads/panoptic_fusion_heads/__init__.py -> build/lib/mmdet/models/seg_heads/panoptic_fusion_heads
# creating build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/global_context_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/scnet_semantic_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/grid_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/mask_point_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/htc_mask_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/fcn_mask_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/coarse_mask_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/feature_relay_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/maskiou_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/scnet_mask_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/fused_semantic_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/dynamic_mask_head.py -> build/lib/mmdet/models/roi_heads/mask_heads
# copying mmdet/models/roi_heads/mask_heads/__init__.py -> build/lib/mmdet/models/roi_heads/mask_heads
# creating build/lib/mmdet/models/roi_heads/bbox_heads
# copying mmdet/models/roi_heads/bbox_heads/scnet_bbox_head.py -> build/lib/mmdet/models/roi_heads/bbox_heads
# copying mmdet/models/roi_heads/bbox_heads/dii_head.py -> build/lib/mmdet/models/roi_heads/bbox_heads
# copying mmdet/models/roi_heads/bbox_heads/sabl_head.py -> build/lib/mmdet/models/roi_heads/bbox_heads
# copying mmdet/models/roi_heads/bbox_heads/double_bbox_head.py -> build/lib/mmdet/models/roi_heads/bbox_heads
# copying mmdet/models/roi_heads/bbox_heads/bbox_head.py -> build/lib/mmdet/models/roi_heads/bbox_heads
# copying mmdet/models/roi_heads/bbox_heads/convfc_bbox_head.py -> build/lib/mmdet/models/roi_heads/bbox_heads
# copying mmdet/models/roi_heads/bbox_heads/__init__.py -> build/lib/mmdet/models/roi_heads/bbox_heads
# creating build/lib/mmdet/models/roi_heads/shared_heads
# copying mmdet/models/roi_heads/shared_heads/res_layer.py -> build/lib/mmdet/models/roi_heads/shared_heads
# copying mmdet/models/roi_heads/shared_heads/__init__.py -> build/lib/mmdet/models/roi_heads/shared_heads
# creating build/lib/mmdet/models/roi_heads/roi_extractors
# copying mmdet/models/roi_heads/roi_extractors/single_level_roi_extractor.py -> build/lib/mmdet/models/roi_heads/roi_extractors
# copying mmdet/models/roi_heads/roi_extractors/base_roi_extractor.py -> build/lib/mmdet/models/roi_heads/roi_extractors
# copying mmdet/models/roi_heads/roi_extractors/__init__.py -> build/lib/mmdet/models/roi_heads/roi_extractors
# copying mmdet/models/roi_heads/roi_extractors/generic_roi_extractor.py -> build/lib/mmdet/models/roi_heads/roi_extractors
# creating build/lib/mmdet/datasets/pipelines
# copying mmdet/datasets/pipelines/test_time_aug.py -> build/lib/mmdet/datasets/pipelines
# copying mmdet/datasets/pipelines/formating.py -> build/lib/mmdet/datasets/pipelines
# copying mmdet/datasets/pipelines/instaboost.py -> build/lib/mmdet/datasets/pipelines
# copying mmdet/datasets/pipelines/compose.py -> build/lib/mmdet/datasets/pipelines
# copying mmdet/datasets/pipelines/auto_augment.py -> build/lib/mmdet/datasets/pipelines
# copying mmdet/datasets/pipelines/formatting.py -> build/lib/mmdet/datasets/pipelines
# copying mmdet/datasets/pipelines/loading.py -> build/lib/mmdet/datasets/pipelines
# copying mmdet/datasets/pipelines/transforms.py -> build/lib/mmdet/datasets/pipelines
# copying mmdet/datasets/pipelines/__init__.py -> build/lib/mmdet/datasets/pipelines
# creating build/lib/mmdet/datasets/api_wrappers
# copying mmdet/datasets/api_wrappers/coco_api.py -> build/lib/mmdet/datasets/api_wrappers
# copying mmdet/datasets/api_wrappers/panoptic_evaluation.py -> build/lib/mmdet/datasets/api_wrappers
# copying mmdet/datasets/api_wrappers/__init__.py -> build/lib/mmdet/datasets/api_wrappers
# creating build/lib/mmdet/datasets/samplers
# copying mmdet/datasets/samplers/distributed_sampler.py -> build/lib/mmdet/datasets/samplers
# copying mmdet/datasets/samplers/class_aware_sampler.py -> build/lib/mmdet/datasets/samplers
# copying mmdet/datasets/samplers/group_sampler.py -> build/lib/mmdet/datasets/samplers
# copying mmdet/datasets/samplers/infinite_sampler.py -> build/lib/mmdet/datasets/samplers
# copying mmdet/datasets/samplers/__init__.py -> build/lib/mmdet/datasets/samplers
# creating build/lib/mmdet/core/visualization
# copying mmdet/core/visualization/image.py -> build/lib/mmdet/core/visualization
# copying mmdet/core/visualization/palette.py -> build/lib/mmdet/core/visualization
# copying mmdet/core/visualization/__init__.py -> build/lib/mmdet/core/visualization
# creating build/lib/mmdet/core/hook
# copying mmdet/core/hook/ema.py -> build/lib/mmdet/core/hook
# copying mmdet/core/hook/yolox_mode_switch_hook.py -> build/lib/mmdet/core/hook
# copying mmdet/core/hook/sync_random_size_hook.py -> build/lib/mmdet/core/hook
# copying mmdet/core/hook/wandblogger_hook.py -> build/lib/mmdet/core/hook
# copying mmdet/core/hook/yolox_lrupdater_hook.py -> build/lib/mmdet/core/hook
# copying mmdet/core/hook/memory_profiler_hook.py -> build/lib/mmdet/core/hook
# copying mmdet/core/hook/checkloss_hook.py -> build/lib/mmdet/core/hook
# copying mmdet/core/hook/sync_norm_hook.py -> build/lib/mmdet/core/hook
# copying mmdet/core/hook/__init__.py -> build/lib/mmdet/core/hook
# copying mmdet/core/hook/set_epoch_info_hook.py -> build/lib/mmdet/core/hook
# creating build/lib/mmdet/core/optimizers
# copying mmdet/core/optimizers/layer_decay_optimizer_constructor.py -> build/lib/mmdet/core/optimizers
# copying mmdet/core/optimizers/builder.py -> build/lib/mmdet/core/optimizers
# copying mmdet/core/optimizers/__init__.py -> build/lib/mmdet/core/optimizers
# creating build/lib/mmdet/core/utils
# copying mmdet/core/utils/dist_utils.py -> build/lib/mmdet/core/utils
# copying mmdet/core/utils/misc.py -> build/lib/mmdet/core/utils
# copying mmdet/core/utils/__init__.py -> build/lib/mmdet/core/utils
# creating build/lib/mmdet/core/post_processing
# copying mmdet/core/post_processing/bbox_nms.py -> build/lib/mmdet/core/post_processing
# copying mmdet/core/post_processing/merge_augs.py -> build/lib/mmdet/core/post_processing
# copying mmdet/core/post_processing/matrix_nms.py -> build/lib/mmdet/core/post_processing
# copying mmdet/core/post_processing/__init__.py -> build/lib/mmdet/core/post_processing
# creating build/lib/mmdet/core/mask
# copying mmdet/core/mask/utils.py -> build/lib/mmdet/core/mask
# copying mmdet/core/mask/mask_target.py -> build/lib/mmdet/core/mask
# copying mmdet/core/mask/structures.py -> build/lib/mmdet/core/mask
# copying mmdet/core/mask/__init__.py -> build/lib/mmdet/core/mask
# creating build/lib/mmdet/core/bbox
# copying mmdet/core/bbox/builder.py -> build/lib/mmdet/core/bbox
# copying mmdet/core/bbox/transforms.py -> build/lib/mmdet/core/bbox
# copying mmdet/core/bbox/demodata.py -> build/lib/mmdet/core/bbox
# copying mmdet/core/bbox/__init__.py -> build/lib/mmdet/core/bbox
# creating build/lib/mmdet/core/evaluation
# copying mmdet/core/evaluation/bbox_overlaps.py -> build/lib/mmdet/core/evaluation
# copying mmdet/core/evaluation/mean_ap.py -> build/lib/mmdet/core/evaluation
# copying mmdet/core/evaluation/panoptic_utils.py -> build/lib/mmdet/core/evaluation
# copying mmdet/core/evaluation/recall.py -> build/lib/mmdet/core/evaluation
# copying mmdet/core/evaluation/class_names.py -> build/lib/mmdet/core/evaluation
# copying mmdet/core/evaluation/eval_hooks.py -> build/lib/mmdet/core/evaluation
# copying mmdet/core/evaluation/__init__.py -> build/lib/mmdet/core/evaluation
# creating build/lib/mmdet/core/export
# copying mmdet/core/export/model_wrappers.py -> build/lib/mmdet/core/export
# copying mmdet/core/export/onnx_helper.py -> build/lib/mmdet/core/export
# copying mmdet/core/export/pytorch2onnx.py -> build/lib/mmdet/core/export
# copying mmdet/core/export/__init__.py -> build/lib/mmdet/core/export
# creating build/lib/mmdet/core/data_structures
# copying mmdet/core/data_structures/general_data.py -> build/lib/mmdet/core/data_structures
# copying mmdet/core/data_structures/__init__.py -> build/lib/mmdet/core/data_structures
# copying mmdet/core/data_structures/instance_data.py -> build/lib/mmdet/core/data_structures
# creating build/lib/mmdet/core/anchor
# copying mmdet/core/anchor/point_generator.py -> build/lib/mmdet/core/anchor
# copying mmdet/core/anchor/utils.py -> build/lib/mmdet/core/anchor
# copying mmdet/core/anchor/anchor_generator.py -> build/lib/mmdet/core/anchor
# copying mmdet/core/anchor/builder.py -> build/lib/mmdet/core/anchor
# copying mmdet/core/anchor/__init__.py -> build/lib/mmdet/core/anchor
# creating build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/combined_sampler.py -> build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/sampling_result.py -> build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/ohem_sampler.py -> build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/mask_pseudo_sampler.py -> build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/base_sampler.py -> build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/random_sampler.py -> build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/iou_balanced_neg_sampler.py -> build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/pseudo_sampler.py -> build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/mask_sampling_result.py -> build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/instance_balanced_pos_sampler.py -> build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/score_hlr_sampler.py -> build/lib/mmdet/core/bbox/samplers
# copying mmdet/core/bbox/samplers/__init__.py -> build/lib/mmdet/core/bbox/samplers
# creating build/lib/mmdet/core/bbox/match_costs
# copying mmdet/core/bbox/match_costs/match_cost.py -> build/lib/mmdet/core/bbox/match_costs
# copying mmdet/core/bbox/match_costs/builder.py -> build/lib/mmdet/core/bbox/match_costs
# copying mmdet/core/bbox/match_costs/__init__.py -> build/lib/mmdet/core/bbox/match_costs
# creating build/lib/mmdet/core/bbox/coder
# copying mmdet/core/bbox/coder/yolo_bbox_coder.py -> build/lib/mmdet/core/bbox/coder
# copying mmdet/core/bbox/coder/pseudo_bbox_coder.py -> build/lib/mmdet/core/bbox/coder
# copying mmdet/core/bbox/coder/bucketing_bbox_coder.py -> build/lib/mmdet/core/bbox/coder
# copying mmdet/core/bbox/coder/tblr_bbox_coder.py -> build/lib/mmdet/core/bbox/coder
# copying mmdet/core/bbox/coder/base_bbox_coder.py -> build/lib/mmdet/core/bbox/coder
# copying mmdet/core/bbox/coder/delta_xywh_bbox_coder.py -> build/lib/mmdet/core/bbox/coder
# copying mmdet/core/bbox/coder/distance_point_bbox_coder.py -> build/lib/mmdet/core/bbox/coder
# copying mmdet/core/bbox/coder/legacy_delta_xywh_bbox_coder.py -> build/lib/mmdet/core/bbox/coder
# copying mmdet/core/bbox/coder/__init__.py -> build/lib/mmdet/core/bbox/coder
# creating build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/grid_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/point_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/uniform_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/center_region_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/assign_result.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/atss_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/ascend_assign_result.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/mask_hungarian_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/ascend_max_iou_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/region_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/approx_max_iou_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/task_aligned_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/sim_ota_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/max_iou_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/__init__.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/base_assigner.py -> build/lib/mmdet/core/bbox/assigners
# copying mmdet/core/bbox/assigners/hungarian_assigner.py -> build/lib/mmdet/core/bbox/assigners
# creating build/lib/mmdet/core/bbox/iou_calculators
# copying mmdet/core/bbox/iou_calculators/iou2d_calculator.py -> build/lib/mmdet/core/bbox/iou_calculators
# copying mmdet/core/bbox/iou_calculators/builder.py -> build/lib/mmdet/core/bbox/iou_calculators
# copying mmdet/core/bbox/iou_calculators/__init__.py -> build/lib/mmdet/core/bbox/iou_calculators
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/mmdet
# copying build/lib/mmdet/version.py -> build/bdist.linux-x86_64/egg/mmdet
# creating build/bdist.linux-x86_64/egg/mmdet/models
# creating build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/res2net.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/swin.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/hrnet.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/efficientnet.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/trident_resnet.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/detectors_resnet.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/hourglass.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/resnext.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/resnet.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/resnest.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/detectors_resnext.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/pvt.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/mobilenet_v2.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/regnet.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/darknet.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/csp_darknet.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/ssd_vgg.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# creating build/bdist.linux-x86_64/egg/mmdet/models/plugins
# copying build/lib/mmdet/models/plugins/pixel_decoder.py -> build/bdist.linux-x86_64/egg/mmdet/models/plugins
# copying build/lib/mmdet/models/plugins/msdeformattn_pixel_decoder.py -> build/bdist.linux-x86_64/egg/mmdet/models/plugins
# copying build/lib/mmdet/models/plugins/dropblock.py -> build/bdist.linux-x86_64/egg/mmdet/models/plugins
# copying build/lib/mmdet/models/plugins/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/plugins
# creating build/bdist.linux-x86_64/egg/mmdet/models/seg_heads
# copying build/lib/mmdet/models/seg_heads/base_semantic_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/seg_heads
# copying build/lib/mmdet/models/seg_heads/panoptic_fpn_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/seg_heads
# creating build/bdist.linux-x86_64/egg/mmdet/models/seg_heads/panoptic_fusion_heads
# copying build/lib/mmdet/models/seg_heads/panoptic_fusion_heads/heuristic_fusion_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/seg_heads/panoptic_fusion_heads
# copying build/lib/mmdet/models/seg_heads/panoptic_fusion_heads/maskformer_fusion_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/seg_heads/panoptic_fusion_heads
# copying build/lib/mmdet/models/seg_heads/panoptic_fusion_heads/base_panoptic_fusion_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/seg_heads/panoptic_fusion_heads
# copying build/lib/mmdet/models/seg_heads/panoptic_fusion_heads/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/seg_heads/panoptic_fusion_heads
# copying build/lib/mmdet/models/seg_heads/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/seg_heads
# creating build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/mask2former_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/embedding_rpn_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/ddod_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/base_dense_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/base_mask_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/corner_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/ga_rpn_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/atss_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/anchor_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/centernet_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/cascade_rpn_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/ga_retina_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/fsaf_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/pisa_ssd_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/yolox_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/nasfcos_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/dense_test_mixins.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/yolact_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/solo_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/autoassign_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/fovea_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/guided_anchor_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/ascend_ssd_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/gfl_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/yolo_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/tood_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/retina_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/ascend_anchor_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/solov2_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/sabl_retina_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/ssd_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/anchor_free_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/vfnet_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/fcos_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/reppoints_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/deformable_detr_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/free_anchor_retina_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/centripetal_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/ascend_retina_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/detr_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/retina_sepbn_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/rpn_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/maskformer_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/lad_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/ld_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/pisa_retinanet_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/paa_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/yolof_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# creating build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/positional_encoding.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/normed_predictor.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/panoptic_gt_processing.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/point_sample.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/se_layer.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/transformer.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/misc.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/csp_layer.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/gaussian_target.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/res_layer.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/conv_upsample.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/inverted_residual.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/ckpt_convert.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/builder.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/brick_wrappers.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/make_divisible.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# creating build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/yolox.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/kd_one_stage.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/retinanet.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/autoassign.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# ...
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/openimages.py to openimages.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/coco.py to coco.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/__init__.py to __init__.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/coco_occluded.py to coco_occluded.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/visualization/image.py to image.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/visualization/palette.py to palette.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/visualization/__init__.py to __init__.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/ema.py to ema.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/yolox_mode_switch_hook.py to yolox_mode_switch_hook.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/sync_random_size_hook.py to sync_random_size_hook.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/wandblogger_hook.py to wandblogger_hook.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/yolox_lrupdater_hook.py to yolox_lrupdater_hook.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/memory_profiler_hook.py to memory_profiler_hook.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/checkloss_hook.py to checkloss_hook.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/sync_norm_hook.py to sync_norm_hook.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/__init__.py to __init__.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/set_epoch_info_hook.py to set_epoch_info_hook.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/optimizers/layer_decay_optimizer_constructor.py to layer_decay_optimizer_constructor.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/optimizers/builder.py to builder.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/optimizers/__init__.py to __init__.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/utils/dist_utils.py to dist_utils.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/utils/misc.py to misc.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/utils/__init__.py to __init__.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/post_processing/bbox_nms.py to bbox_nms.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/post_processing/merge_augs.py to merge_augs.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/post_processing/matrix_nms.py to matrix_nms.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/post_processing/__init__.py to __init__.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/mask/utils.py to utils.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/mask/mask_target.py to mask_target.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/mask/structures.py to structures.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/mask/__init__.py to __init__.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/combined_sampler.py to combined_sampler.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/sampling_result.py to sampling_result.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/ohem_sampler.py to ohem_sampler.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/mask_pseudo_sampler.py to mask_pseudo_sampler.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/base_sampler.py to base_sampler.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/random_sampler.py to random_sampler.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/iou_balanced_neg_sampler.py to iou_balanced_neg_sampler.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/pseudo_sampler.py to pseudo_sampler.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/mask_sampling_result.py to mask_sampling_result.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/instance_balanced_pos_sampler.py to instance_balanced_pos_sampler.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/score_hlr_sampler.py to score_hlr_sampler.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/__init__.py to __init__.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/match_costs/match_cost.py to match_cost.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/match_costs/builder.py to builder.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/match_costs/__init__.py to __init__.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/builder.py to builder.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/transforms.py to transforms.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/demodata.py to demodata.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/__init__.py to __init__.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/yolo_bbox_coder.py to yolo_bbox_coder.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/pseudo_bbox_coder.py to pseudo_bbox_coder.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/bucketing_bbox_coder.py to bucketing_bbox_coder.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/tblr_bbox_coder.py to tblr_bbox_coder.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/base_bbox_coder.py to base_bbox_coder.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/delta_xywh_bbox_coder.py to delta_xywh_bbox_coder.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/distance_point_bbox_coder.py to distance_point_bbox_coder.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/legacy_delta_xywh_bbox_coder.py to legacy_delta_xywh_bbox_coder.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/__init__.py to __init__.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/grid_assigner.py to grid_assigner.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/point_assigner.py to point_assigner.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/uniform_assigner.py to uniform_assigner.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/center_region_assigner.py to center_region_assigner.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/assign_result.py to assign_result.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/atss_assigner.py to atss_assigner.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/ascend_assign_result.py to ascend_assign_result.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/mask_hungarian_assigner.py to mask_hungarian_assigner.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/ascend_max_iou_assigner.py to ascend_max_iou_assigner.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/region_assigner.py to region_assigner.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/approx_max_iou_assigner.py to approx_max_iou_assigner.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/task_aligned_assigner.py to task_aligned_assigner.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/sim_ota_assigner.py to sim_ota_assigner.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/max_iou_assigner.py to max_iou_assigner.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/__init__.py to __init__.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/base_assigner.py to base_assigner.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/hungarian_assigner.py to hungarian_assigner.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/iou_calculators/iou2d_calculator.py to iou2d_calculator.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/iou_calculators/builder.py to builder.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/iou_calculators/__init__.py to __init__.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/evaluation/bbox_overlaps.py to bbox_overlaps.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/evaluation/mean_ap.py to mean_ap.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/evaluation/panoptic_utils.py to panoptic_utils.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/evaluation/recall.py to recall.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/evaluation/class_names.py to class_names.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/evaluation/eval_hooks.py to eval_hooks.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/evaluation/__init__.py to __init__.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/export/model_wrappers.py to model_wrappers.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/export/onnx_helper.py to onnx_helper.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/export/pytorch2onnx.py to pytorch2onnx.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/export/__init__.py to __init__.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/data_structures/general_data.py to general_data.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/data_structures/__init__.py to __init__.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/data_structures/instance_data.py to instance_data.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/__init__.py to __init__.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/anchor/point_generator.py to point_generator.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/anchor/utils.py to utils.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/anchor/anchor_generator.py to anchor_generator.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/anchor/builder.py to builder.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/anchor/__init__.py to __init__.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/apis/test.py to test.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/apis/train.py to train.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/apis/inference.py to inference.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/apis/__init__.py to __init__.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/__init__.py to __init__.cpython-311.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying mmdet.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mmdet.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mmdet.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mmdet.egg-info/not-zip-safe -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mmdet.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mmdet.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# creating dist
# creating 'dist/mmdet-2.28.2-py3.11.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing mmdet-2.28.2-py3.11.egg
# creating /usr/local/lib/python3.11/dist-packages/mmdet-2.28.2-py3.11.egg
# Extracting mmdet-2.28.2-py3.11.egg to /usr/local/lib/python3.11/dist-packages
# Adding mmdet 2.28.2 to easy-install.pth file
#
# Installed /usr/local/lib/python3.11/dist-packages/mmdet-2.28.2-py3.11.egg
# Processing dependencies for mmdet==2.28.2
# Searching for terminaltables
# Reading https://pypi.org/simple/terminaltables/
# Downloading https://files.pythonhosted.org/packages/c4/fb/ea621e0a19733e01fe4005d46087d383693c0f4a8f824b47d8d4122c87e0/terminaltables-3.1.10-py2.py3-none-any.whl#sha256=e4fdc4179c9e4aab5f674d80f09d76fa436b96fdc698a8505e0a36bf0804a874
# Best match: terminaltables 3.1.10
# Processing terminaltables-3.1.10-py2.py3-none-any.whl
# Installing terminaltables-3.1.10-py2.py3-none-any.whl to /usr/local/lib/python3.11/dist-packages
# Adding terminaltables 3.1.10 to easy-install.pth file
# detected new path './mmdet-2.28.2-py3.11.egg'
#
# Installed /usr/local/lib/python3.11/dist-packages/terminaltables-3.1.10-py3.11.egg
# Searching for six==1.17.0
# Best match: six 1.17.0
# Adding six 1.17.0 to easy-install.pth file
# detected new path './terminaltables-3.1.10-py3.11.egg'
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for scipy==1.13.1
# Best match: scipy 1.13.1
# Adding scipy 1.13.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for pycocotools==2.0.8
# Best match: pycocotools 2.0.8
# Adding pycocotools 2.0.8 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for numpy==1.26.4
# Best match: numpy 1.26.4
# Adding numpy 1.26.4 to easy-install.pth file
# Installing f2py script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for matplotlib==3.10.0
# Best match: matplotlib 3.10.0
# Adding matplotlib 3.10.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for python-dateutil==2.8.2
# Best match: python-dateutil 2.8.2
# Adding python-dateutil 2.8.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for pyparsing==3.2.1
# Best match: pyparsing 3.2.1
# Adding pyparsing 3.2.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for pillow==11.1.0
# Best match: pillow 11.1.0
# Adding pillow 11.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for packaging==24.2
# Best match: packaging 24.2
# Adding packaging 24.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for kiwisolver==1.4.8
# Best match: kiwisolver 1.4.8
# Adding kiwisolver 1.4.8 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for fonttools==4.56.0
# Best match: fonttools 4.56.0
# Adding fonttools 4.56.0 to easy-install.pth file
# Installing fonttools script to /usr/local/bin
# Installing pyftmerge script to /usr/local/bin
# Installing pyftsubset script to /usr/local/bin
# Installing ttx script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for cycler==0.12.1
# Best match: cycler 0.12.1
# Adding cycler 0.12.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for contourpy==1.3.1
# Best match: contourpy 1.3.1
# Adding contourpy 1.3.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Finished processing dependencies for mmdet==2.28.2

# %%
# 아래를 수행하기 전에 kernel을 restart 해야 함.
from mmdet.apis import init_detector, inference_detector
import mmcv

# %%
### 반드시 numpy downgrade를 mmcv 설치 후에 실행할것.
# !pip install numpy==1.23
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/mmdet-2.28.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/terminaltables-3.1.10-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Collecting numpy==1.23
#   Downloading numpy-1.23.0.tar.gz (10.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 84.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: numpy
#   Building wheel for numpy (pyproject.toml) ... done
#   Created wheel for numpy: filename=numpy-1.23.0-cp311-cp311-linux_x86_64.whl size=19730332 sha256=d946dbb4feb0d7226522bff2a6a541c8814e3e6a66877edc46899b8f55747bf4
#   Stored in directory: /root/.cache/pip/wheels/6d/36/1a/3ec6b85008bea3151efb003f5d41baa7bf4966cb43c1c2470b
# Successfully built numpy
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-contrib-python 4.11.0.86 requires numpy>=1.23.5; python_version >= "3.11", but you have numpy 1.23.0 which is incompatible.
# xarray 2025.1.2 requires numpy>=1.24, but you have numpy 1.23.0 which is incompatible.
# jax 0.4.33 requires numpy>=1.24, but you have numpy 1.23.0 which is incompatible.
# astropy 7.0.1 requires numpy>=1.23.2, but you have numpy 1.23.0 which is incompatible.
# ml-dtypes 0.4.1 requires numpy>=1.23.3; python_version >= "3.11", but you have numpy 1.23.0 which is incompatible.
# chex 0.1.89 requires numpy>=1.24.1, but you have numpy 1.23.0 which is incompatible.
# numba 0.61.0 requires numpy<2.2,>=1.24, but you have numpy 1.23.0 which is incompatible.
# scikit-image 0.25.2 requires numpy>=1.24, but you have numpy 1.23.0 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 1.23.0 which is incompatible.
# langchain 0.3.19 requires numpy<2,>=1.26.4; python_version < "3.12", but you have numpy 1.23.0 which is incompatible.
# mizani 0.13.1 requires numpy>=1.23.5, but you have numpy 1.23.0 which is incompatible.
# bigframes 1.38.0 requires numpy>=1.24.0, but you have numpy 1.23.0 which is incompatible.
# pandas 2.2.2 requires numpy>=1.23.2; python_version == "3.11", but you have numpy 1.23.0 which is incompatible.
# blosc2 3.1.1 requires numpy>=1.25.0, but you have numpy 1.23.0 which is incompatible.
# pandas-stubs 2.2.2.240909 requires numpy>=1.23.5, but you have numpy 1.23.0 which is incompatible.
# ibis-framework 9.2.0 requires numpy<3,>=1.23.2, but you have numpy 1.23.0 which is incompatible.
# dm-tree 0.1.9 requires numpy>=1.23.3; python_version >= "3.11", but you have numpy 1.23.0 which is incompatible.
# opencv-python 4.11.0.86 requires numpy>=1.23.5; python_version >= "3.11", but you have numpy 1.23.0 which is incompatible.
# flax 0.10.3 requires numpy>=1.23.2; python_version >= "3.11", but you have numpy 1.23.0 which is incompatible.
# plotnine 0.14.5 requires numpy>=1.23.5, but you have numpy 1.23.0 which is incompatible.
# opencv-python-headless 4.11.0.86 requires numpy>=1.23.5; python_version >= "3.11", but you have numpy 1.23.0 which is incompatible.
# treescope 0.1.9 requires numpy>=1.25.2, but you have numpy 1.23.0 which is incompatible.
# jaxlib 0.4.33 requires numpy>=1.24, but you have numpy 1.23.0 which is incompatible.
# imbalanced-learn 0.13.0 requires numpy<3,>=1.24.3, but you have numpy 1.23.0 which is incompatible.
# pymc 5.20.1 requires numpy>=1.25.0, but you have numpy 1.23.0 which is incompatible.
# albucore 0.0.23 requires numpy>=1.24.4, but you have numpy 1.23.0 which is incompatible.
# albumentations 2.0.4 requires numpy>=1.24.4, but you have numpy 1.23.0 which is incompatible.
# Successfully installed numpy-1.23.0

# %%
# 파이썬 코드 포매터 설치
# !pip install yapf==0.40.1
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/mmdet-2.28.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/terminaltables-3.1.10-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Collecting yapf==0.40.1
#   Downloading yapf-0.40.1-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /usr/local/lib/python3.11/dist-packages (from yapf==0.40.1) (8.6.1)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.11/dist-packages (from yapf==0.40.1) (4.3.6)
# Collecting tomli>=2.0.1 (from yapf==0.40.1)
#   Downloading tomli-2.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=6.6.0->yapf==0.40.1) (3.21.0)
# Downloading yapf-0.40.1-py3-none-any.whl (250 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.3/250.3 kB 26.0 MB/s eta 0:00:00
# Downloading tomli-2.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (236 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.0/236.0 kB 24.5 MB/s eta 0:00:00
# Installing collected packages: tomli, yapf
#   Attempting uninstall: yapf
#     Found existing installation: yapf 0.43.0
#     Uninstalling yapf-0.43.0:
#       Successfully uninstalled yapf-0.43.0
# Successfully installed tomli-2.2.1 yapf-0.40.1

# %% [markdown]
# ### PASCAL VOC형태의 BCCD Dataset를 Download 후 MS-COCO 형태로 변경

# %%
import os

# BCCD_Dataset 클론
# !git clone https://github.com/Shenggan/BCCD_Dataset.git

# voc -> coco 변환 도구 클론
# !git clone https://github.com/yukkyo/voc2coco.git

# labels.txt 수정.
#  "WBC", "RBC", "Platelets" 클래스 추가
with open('/content/BCCD_Dataset/BCCD/labels.txt', "w") as f:
    f.write("WBC\n")
    f.write("RBC\n")
    f.write("Platelets\n")

# VOC를 COCO로 변환 수행.
# 학습/검증/테스트 용 json annotation을 생성.
# %cd voc2coco
# !python voc2coco.py --ann_dir /content/BCCD_Dataset/BCCD/Annotations \
--ann_ids /content/BCCD_Dataset/BCCD/ImageSets/Main/train.txt \
--labels /content/BCCD_Dataset/BCCD/labels.txt \
--output /content/BCCD_Dataset/BCCD/train.json \
--ext xml

# !python voc2coco.py --ann_dir /content/BCCD_Dataset/BCCD/Annotations \
--ann_ids /content/BCCD_Dataset/BCCD/ImageSets/Main/val.txt \
--labels /content/BCCD_Dataset/BCCD/labels.txt \
--output /content/BCCD_Dataset/BCCD/val.json \
--ext xml

# !python voc2coco.py --ann_dir /content/BCCD_Dataset/BCCD/Annotations \
--ann_ids /content/BCCD_Dataset/BCCD/ImageSets/Main/test.txt \
--labels /content/BCCD_Dataset/BCCD/labels.txt \
--output /content/BCCD_Dataset/BCCD/test.json \
--ext xml

# annotation.json 파일을 잘 볼수 있는 jq 유틸리티 셋업.
# !sudo apt-get install jq

# 각 파일을 읽기 쉽게 변환 후 결과를 output.json에 저장.
# !jq . /content/BCCD_Dataset/BCCD/train.json > output.json
# !jq . /content/BCCD_Dataset/BCCD/test.json > output.json
# Out:
# Cloning into 'BCCD_Dataset'...
# remote: Enumerating objects: 800, done.
# remote: Total 800 (delta 0), reused 0 (delta 0), pack-reused 800 (from 1)
# Receiving objects: 100% (800/800), 7.39 MiB | 7.77 MiB/s, done.
# Resolving deltas: 100% (378/378), done.
# Cloning into 'voc2coco'...
# remote: Enumerating objects: 436, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 436 (delta 19), reused 11 (delta 11), pack-reused 408 (from 1)
# Receiving objects: 100% (436/436), 214.06 KiB | 11.89 MiB/s, done.
# Resolving deltas: 100% (390/390), done.
# /content/voc2coco
# Start converting !
# 100% 205/205 [00:00<00:00, 5504.20it/s]
# Start converting !
# 100% 87/87 [00:00<00:00, 5760.68it/s]
# Start converting !
# 100% 72/72 [00:00<00:00, 5763.06it/s]
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libjq1 libonig5
# The following NEW packages will be installed:
#   jq libjq1 libonig5
# 0 upgraded, 3 newly installed, 0 to remove and 29 not upgraded.
# Need to get 357 kB of archives.
# After this operation, 1,087 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libonig5 amd64 6.9.7.1-2build1 [172 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjq1 amd64 1.6-2.1ubuntu3 [133 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 jq amd64 1.6-2.1ubuntu3 [52.5 kB]
# Fetched 357 kB in 2s (227 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 3.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libonig5:amd64.
# (Reading database ... 124947 files and directories currently installed.)
# Preparing to unpack .../libonig5_6.9.7.1-2build1_amd64.deb ...
# Unpacking libonig5:amd64 (6.9.7.1-2build1) ...
# Selecting previously unselected package libjq1:amd64.
# Preparing to unpack .../libjq1_1.6-2.1ubuntu3_amd64.deb ...
# Unpacking libjq1:amd64 (1.6-2.1ubuntu3) ...
# Selecting previously unselected package jq.
# Preparing to unpack .../jq_1.6-2.1ubuntu3_amd64.deb ...
# Unpacking jq (1.6-2.1ubuntu3) ...
# Setting up libonig5:amd64 (6.9.7.1-2build1) ...
# Setting up libjq1:amd64 (1.6-2.1ubuntu3) ...
# Setting up jq (1.6-2.1ubuntu3) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link

# %% [markdown]
# ### CocoDataset 클래스를 활용하여 BCCD Dataset을 로딩하기
# * MS-COCO Dataset의 경우 별다른 Custom Code없이 Object들의 Class만 지정해 주면 됨

# %%
# %cd /content

from mmdet.datasets.builder import DATASETS
from mmdet.datasets.coco import CocoDataset

@DATASETS.register_module(force=True)
class BCCDDataset(CocoDataset):
  CLASSES = ('WBC', 'RBC', 'Platelets')
# Out:
# /content
# /usr/local/lib/python3.11/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/albumentations/__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.5' (you have '2.0.4'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %% [markdown]
# ### Config 설정하고 Checkpoint 파일 다운로드 받기

# %%
from mmcv import Config
from mmdet.apis import set_random_seed

# config 파일과 pretrained 가중치 경로 설정
config_file = '/content/mmdetection/configs/faster_rcnn/faster_rcnn_r50_fpn_1x_coco.py'
checkpoint_file = '/content/mmdetection/checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth'

# pretrained 가중치 다운로드
# !cd /content/mmdetection; mkdir checkpoints
# !wget -O /content/mmdetection/checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth http://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth

# config 파일 불러오기
cfg = Config.fromfile(config_file)

# config파일 수정하기
# dataset에 대한 환경 파라미터 수정.
cfg.dataset_type = 'BCCDDataset'
cfg.data_root = '/content/BCCD_Dataset/BCCD/'

# train, val, test dataset에 대한 type, data_root, ann_file, img_prefix 환경 파라미터 수정.
cfg.data.train.type = 'BCCDDataset'
cfg.data.train.data_root = '/content/BCCD_Dataset/BCCD/'
cfg.data.train.ann_file = 'train.json'
cfg.data.train.img_prefix = 'JPEGImages'

cfg.data.val.type = 'BCCDDataset'
cfg.data.val.data_root = '/content/BCCD_Dataset/BCCD/'
cfg.data.val.ann_file = 'val.json'
cfg.data.val.img_prefix = 'JPEGImages'

cfg.data.test.type = 'BCCDDataset'
cfg.data.test.data_root = '/content/BCCD_Dataset/BCCD/'
cfg.data.test.ann_file = 'test.json'
cfg.data.test.img_prefix = 'JPEGImages'

# class의 갯수 수정.
cfg.model.roi_head.bbox_head.num_classes = 3
# pretrained 모델
cfg.load_from = '/content/mmdetection/checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth'

# 학습 weight 파일로 로그를 저장하기 위한 디렉토리 설정.
cfg.work_dir = './tutorial_exps'

# 학습율 변경 환경 파라미터 설정.
cfg.optimizer.lr = 0.02 / 8
cfg.lr_config.warmup = None
cfg.log_config.interval = 10

# CocoDataset의 경우 metric을 bbox로 설정해야 함.(mAP아님. bbox로 설정하면 mAP를 iou threshold를 0.5 ~ 0.95까지 변경하면서 측정)
cfg.evaluation.metric = 'bbox'
cfg.evaluation.interval = 12
cfg.checkpoint_config.interval = 12

# 두번 config를 로드하면 lr_config의 policy가 사라지는 오류로 인하여 설정.
cfg.lr_config.policy='step'
# Set seed thus the results are more reproducible
cfg.seed = 0
set_random_seed(0, deterministic=False)
cfg.gpu_ids = range(1)
# ConfigDict' object has no attribute 'device 오류 발생시 반드시 설정 필요. https://github.com/open-mmlab/mmdetection/issues/7901
cfg.device='cuda'
# Out:
# --2025-03-01 11:18:44--  http://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth
# Resolving download.openmmlab.com (download.openmmlab.com)... 163.181.42.203, 163.181.42.178, 163.181.42.204, ...
# Connecting to download.openmmlab.com (download.openmmlab.com)|163.181.42.203|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 167287506 (160M) [application/octet-stream]
# Saving to: ‘/content/mmdetection/checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth’
#
# /content/mmdetectio 100%[===================>] 159.54M  28.5MB/s    in 5.8s
#
# 2025-03-01 11:18:50 (27.5 MB/s) - ‘/content/mmdetection/checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth’ saved [167287506/167287506]

# %% [markdown]
# ### Dataset을 만들고, 모델 학습 및 Inference 적용

# %%
from mmdet.datasets import build_dataset
from mmdet.models import build_detector
from mmdet.apis import train_detector
import os.path as osp

# train용 Dataset 생성.
datasets = [build_dataset(cfg.data.train)]

# 모델 생성
model = build_detector(cfg.model, train_cfg=cfg.get('train_cfg'), test_cfg=cfg.get('test_cfg'))
model.CLASSES = datasets[0].CLASSES

mmcv.mkdir_or_exist(osp.abspath(cfg.work_dir))

# 모델 훈련
# epochs는 config의 runner 파라미터로 지정됨. 기본 12회
train_detector(model, datasets, cfg, distributed=False, validate=True)
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# 2025-03-01 11:21:39,669 - mmdet - INFO - Automatic scaling of learning rate (LR) has been disabled.
# 2025-03-01 11:21:39,677 - mmdet - INFO - load checkpoint from local path: /content/mmdetection/checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 2025-03-01 11:21:39,891 - mmdet - WARNING - The model and loaded state dict do not match exactly
#
# size mismatch for roi_head.bbox_head.fc_cls.weight: copying a param with shape torch.Size([81, 1024]) from checkpoint, the shape in current model is torch.Size([4, 1024]).
# size mismatch for roi_head.bbox_head.fc_cls.bias: copying a param with shape torch.Size([81]) from checkpoint, the shape in current model is torch.Size([4]).
# size mismatch for roi_head.bbox_head.fc_reg.weight: copying a param with shape torch.Size([320, 1024]) from checkpoint, the shape in current model is torch.Size([12, 1024]).
# size mismatch for roi_head.bbox_head.fc_reg.bias: copying a param with shape torch.Size([320]) from checkpoint, the shape in current model is torch.Size([12]).
# 2025-03-01 11:21:39,914 - mmdet - INFO - Start running, host: root@5ac9ef5a74a6, work_dir: /content/tutorial_exps
# 2025-03-01 11:21:39,915 - mmdet - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) NumClassCheckHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) StepLrUpdaterHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
#  --------------------
# after_train_iter:
# (ABOVE_NORMAL) OptimizerHook
# (NORMAL      ) CheckpointHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) NumClassCheckHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_epoch:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_run:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# 2025-03-01 11:21:39,922 - mmdet - INFO - workflow: [('train', 1)], max: 12 epochs
# 2025-03-01 11:21:39,923 - mmdet - INFO - Checkpoints will be saved to /content/tutorial_exps by HardDiskBackend.
# 2025-03-01 11:21:48,658 - mmdet - INFO - Epoch [1][10/103]	lr: 2.500e-03, eta: 0:17:18, time: 0.847, data_time: 0.241, memory: 3072, loss_rpn_cls: 0.1473, loss_rpn_bbox: 0.0884, loss_cls: 0.7775, acc: 70.7812, loss_bbox: 0.7981, loss: 1.8112
# 2025-03-01 11:21:53,588 - mmdet - INFO - Epoch [1][20/103]	lr: 2.500e-03, eta: 0:13:34, time: 0.493, data_time: 0.041, memory: 3072, loss_rpn_cls: 0.0334, loss_rpn_bbox: 0.0664, loss_cls: 0.4760, acc: 83.2715, loss_bbox: 0.6330, loss: 1.2088
# 2025-03-01 11:21:58,475 - mmdet - INFO - Epoch [1][30/103]	lr: 2.500e-03, eta: 0:12:15, time: 0.489, data_time: 0.037, memory: 3073, loss_rpn_cls: 0.0186, loss_rpn_bbox: 0.0783, loss_cls: 0.3646, acc: 86.2598, loss_bbox: 0.5114, loss: 0.9728
# 2025-03-01 11:22:03,396 - mmdet - INFO - Epoch [1][40/103]	lr: 2.500e-03, eta: 0:11:34, time: 0.493, data_time: 0.037, memory: 3073, loss_rpn_cls: 0.0257, loss_rpn_bbox: 0.0897, loss_cls: 0.3529, acc: 85.9277, loss_bbox: 0.4580, loss: 0.9263
# 2025-03-01 11:22:08,399 - mmdet - INFO - Epoch [1][50/103]	lr: 2.500e-03, eta: 0:11:09, time: 0.499, data_time: 0.040, memory: 3074, loss_rpn_cls: 0.0241, loss_rpn_bbox: 0.0783, loss_cls: 0.3543, acc: 85.3613, loss_bbox: 0.4885, loss: 0.9452
# 2025-03-01 11:22:13,358 - mmdet - INFO - Epoch [1][60/103]	lr: 2.500e-03, eta: 0:10:50, time: 0.496, data_time: 0.039, memory: 3074, loss_rpn_cls: 0.0156, loss_rpn_bbox: 0.0662, loss_cls: 0.3085, acc: 87.2754, loss_bbox: 0.4271, loss: 0.8175
# 2025-03-01 11:22:18,404 - mmdet - INFO - Epoch [1][70/103]	lr: 2.500e-03, eta: 0:10:36, time: 0.504, data_time: 0.040, memory: 3074, loss_rpn_cls: 0.0250, loss_rpn_bbox: 0.0588, loss_cls: 0.3126, acc: 86.3281, loss_bbox: 0.4363, loss: 0.8327
# 2025-03-01 11:22:23,445 - mmdet - INFO - Epoch [1][80/103]	lr: 2.500e-03, eta: 0:10:24, time: 0.504, data_time: 0.040, memory: 3074, loss_rpn_cls: 0.0167, loss_rpn_bbox: 0.0620, loss_cls: 0.2750, acc: 87.9102, loss_bbox: 0.3750, loss: 0.7287
# 2025-03-01 11:22:28,551 - mmdet - INFO - Epoch [1][90/103]	lr: 2.500e-03, eta: 0:10:15, time: 0.511, data_time: 0.039, memory: 3074, loss_rpn_cls: 0.0129, loss_rpn_bbox: 0.0586, loss_cls: 0.2751, acc: 87.5488, loss_bbox: 0.3774, loss: 0.7239
# 2025-03-01 11:22:33,693 - mmdet - INFO - Epoch [1][100/103]	lr: 2.500e-03, eta: 0:10:07, time: 0.513, data_time: 0.036, memory: 3074, loss_rpn_cls: 0.0196, loss_rpn_bbox: 0.0560, loss_cls: 0.2597, acc: 88.0957, loss_bbox: 0.3569, loss: 0.6921
# 2025-03-01 11:22:42,491 - mmdet - INFO - Epoch [2][10/103]	lr: 2.500e-03, eta: 0:10:03, time: 0.720, data_time: 0.232, memory: 3074, loss_rpn_cls: 0.0129, loss_rpn_bbox: 0.0591, loss_cls: 0.2578, acc: 88.2129, loss_bbox: 0.3581, loss: 0.6879
# 2025-03-01 11:22:47,713 - mmdet - INFO - Epoch [2][20/103]	lr: 2.500e-03, eta: 0:09:56, time: 0.521, data_time: 0.038, memory: 3074, loss_rpn_cls: 0.0151, loss_rpn_bbox: 0.0624, loss_cls: 0.2368, acc: 89.6289, loss_bbox: 0.3780, loss: 0.6923
# 2025-03-01 11:22:53,030 - mmdet - INFO - Epoch [2][30/103]	lr: 2.500e-03, eta: 0:09:50, time: 0.532, data_time: 0.043, memory: 3074, loss_rpn_cls: 0.0184, loss_rpn_bbox: 0.0565, loss_cls: 0.2316, acc: 89.7949, loss_bbox: 0.3172, loss: 0.6238
# 2025-03-01 11:22:58,309 - mmdet - INFO - Epoch [2][40/103]	lr: 2.500e-03, eta: 0:09:44, time: 0.528, data_time: 0.038, memory: 3074, loss_rpn_cls: 0.0155, loss_rpn_bbox: 0.0626, loss_cls: 0.2522, acc: 88.7305, loss_bbox: 0.3833, loss: 0.7136
# 2025-03-01 11:23:03,669 - mmdet - INFO - Epoch [2][50/103]	lr: 2.500e-03, eta: 0:09:39, time: 0.536, data_time: 0.041, memory: 3074, loss_rpn_cls: 0.0202, loss_rpn_bbox: 0.0554, loss_cls: 0.2518, acc: 88.5938, loss_bbox: 0.3338, loss: 0.6613
# 2025-03-01 11:23:09,101 - mmdet - INFO - Epoch [2][60/103]	lr: 2.500e-03, eta: 0:09:34, time: 0.543, data_time: 0.042, memory: 3074, loss_rpn_cls: 0.0105, loss_rpn_bbox: 0.0451, loss_cls: 0.2435, acc: 88.8086, loss_bbox: 0.3050, loss: 0.6041
# 2025-03-01 11:23:14,588 - mmdet - INFO - Epoch [2][70/103]	lr: 2.500e-03, eta: 0:09:30, time: 0.548, data_time: 0.039, memory: 3074, loss_rpn_cls: 0.0144, loss_rpn_bbox: 0.0531, loss_cls: 0.2631, acc: 88.3887, loss_bbox: 0.3688, loss: 0.6993
# 2025-03-01 11:23:20,175 - mmdet - INFO - Epoch [2][80/103]	lr: 2.500e-03, eta: 0:09:25, time: 0.558, data_time: 0.043, memory: 3074, loss_rpn_cls: 0.0110, loss_rpn_bbox: 0.0521, loss_cls: 0.2565, acc: 88.3789, loss_bbox: 0.3303, loss: 0.6499
# 2025-03-01 11:23:25,757 - mmdet - INFO - Epoch [2][90/103]	lr: 2.500e-03, eta: 0:09:21, time: 0.558, data_time: 0.040, memory: 3074, loss_rpn_cls: 0.0094, loss_rpn_bbox: 0.0514, loss_cls: 0.2252, acc: 90.4688, loss_bbox: 0.3207, loss: 0.6067
# 2025-03-01 11:23:31,326 - mmdet - INFO - Epoch [2][100/103]	lr: 2.500e-03, eta: 0:09:17, time: 0.558, data_time: 0.042, memory: 3074, loss_rpn_cls: 0.0156, loss_rpn_bbox: 0.0547, loss_cls: 0.2712, acc: 87.4805, loss_bbox: 0.3328, loss: 0.6743
# 2025-03-01 11:23:40,427 - mmdet - INFO - Epoch [3][10/103]	lr: 2.500e-03, eta: 0:09:12, time: 0.740, data_time: 0.234, memory: 3074, loss_rpn_cls: 0.0130, loss_rpn_bbox: 0.0486, loss_cls: 0.2125, acc: 90.7812, loss_bbox: 0.3299, loss: 0.6039
# 2025-03-01 11:23:45,796 - mmdet - INFO - Epoch [3][20/103]	lr: 2.500e-03, eta: 0:09:06, time: 0.536, data_time: 0.038, memory: 3074, loss_rpn_cls: 0.0135, loss_rpn_bbox: 0.0584, loss_cls: 0.2424, acc: 89.3652, loss_bbox: 0.3461, loss: 0.6603
# 2025-03-01 11:23:51,140 - mmdet - INFO - Epoch [3][30/103]	lr: 2.500e-03, eta: 0:09:00, time: 0.536, data_time: 0.040, memory: 3074, loss_rpn_cls: 0.0133, loss_rpn_bbox: 0.0529, loss_cls: 0.2199, acc: 90.2539, loss_bbox: 0.3135, loss: 0.5996
# 2025-03-01 11:23:56,516 - mmdet - INFO - Epoch [3][40/103]	lr: 2.500e-03, eta: 0:08:55, time: 0.537, data_time: 0.043, memory: 3074, loss_rpn_cls: 0.0118, loss_rpn_bbox: 0.0575, loss_cls: 0.2299, acc: 89.7461, loss_bbox: 0.3292, loss: 0.6284
# 2025-03-01 11:24:01,840 - mmdet - INFO - Epoch [3][50/103]	lr: 2.500e-03, eta: 0:08:49, time: 0.533, data_time: 0.038, memory: 3074, loss_rpn_cls: 0.0117, loss_rpn_bbox: 0.0521, loss_cls: 0.2391, acc: 89.3164, loss_bbox: 0.3190, loss: 0.6220
# 2025-03-01 11:24:07,191 - mmdet - INFO - Epoch [3][60/103]	lr: 2.500e-03, eta: 0:08:43, time: 0.534, data_time: 0.041, memory: 3074, loss_rpn_cls: 0.0165, loss_rpn_bbox: 0.0466, loss_cls: 0.2867, acc: 86.6504, loss_bbox: 0.2956, loss: 0.6455
# 2025-03-01 11:24:12,508 - mmdet - INFO - Epoch [3][70/103]	lr: 2.500e-03, eta: 0:08:38, time: 0.532, data_time: 0.039, memory: 3074, loss_rpn_cls: 0.0131, loss_rpn_bbox: 0.0496, loss_cls: 0.2225, acc: 90.3516, loss_bbox: 0.3272, loss: 0.6125
# 2025-03-01 11:24:17,896 - mmdet - INFO - Epoch [3][80/103]	lr: 2.500e-03, eta: 0:08:32, time: 0.539, data_time: 0.040, memory: 3074, loss_rpn_cls: 0.0100, loss_rpn_bbox: 0.0488, loss_cls: 0.2388, acc: 89.9414, loss_bbox: 0.3029, loss: 0.6005
# 2025-03-01 11:24:23,268 - mmdet - INFO - Epoch [3][90/103]	lr: 2.500e-03, eta: 0:08:27, time: 0.537, data_time: 0.039, memory: 3074, loss_rpn_cls: 0.0110, loss_rpn_bbox: 0.0540, loss_cls: 0.2302, acc: 89.5996, loss_bbox: 0.3529, loss: 0.6480
# 2025-03-01 11:24:28,705 - mmdet - INFO - Epoch [3][100/103]	lr: 2.500e-03, eta: 0:08:22, time: 0.543, data_time: 0.038, memory: 3074, loss_rpn_cls: 0.0136, loss_rpn_bbox: 0.0510, loss_cls: 0.2330, acc: 89.8730, loss_bbox: 0.2943, loss: 0.5919
# 2025-03-01 11:24:37,770 - mmdet - INFO - Epoch [4][10/103]	lr: 2.500e-03, eta: 0:08:15, time: 0.736, data_time: 0.229, memory: 3074, loss_rpn_cls: 0.0164, loss_rpn_bbox: 0.0584, loss_cls: 0.2635, acc: 87.8809, loss_bbox: 0.3115, loss: 0.6498
# 2025-03-01 11:24:43,257 - mmdet - INFO - Epoch [4][20/103]	lr: 2.500e-03, eta: 0:08:10, time: 0.549, data_time: 0.044, memory: 3074, loss_rpn_cls: 0.0138, loss_rpn_bbox: 0.0483, loss_cls: 0.2328, acc: 89.6094, loss_bbox: 0.3040, loss: 0.5989
# 2025-03-01 11:24:48,683 - mmdet - INFO - Epoch [4][30/103]	lr: 2.500e-03, eta: 0:08:05, time: 0.542, data_time: 0.039, memory: 3074, loss_rpn_cls: 0.0148, loss_rpn_bbox: 0.0532, loss_cls: 0.2373, acc: 89.3359, loss_bbox: 0.3387, loss: 0.6440
# 2025-03-01 11:24:54,186 - mmdet - INFO - Epoch [4][40/103]	lr: 2.500e-03, eta: 0:08:00, time: 0.550, data_time: 0.045, memory: 3074, loss_rpn_cls: 0.0121, loss_rpn_bbox: 0.0454, loss_cls: 0.2167, acc: 90.3418, loss_bbox: 0.3006, loss: 0.5747
# 2025-03-01 11:24:59,631 - mmdet - INFO - Epoch [4][50/103]	lr: 2.500e-03, eta: 0:07:54, time: 0.545, data_time: 0.040, memory: 3074, loss_rpn_cls: 0.0086, loss_rpn_bbox: 0.0523, loss_cls: 0.2399, acc: 89.0723, loss_bbox: 0.3112, loss: 0.6120
# 2025-03-01 11:25:05,107 - mmdet - INFO - Epoch [4][60/103]	lr: 2.500e-03, eta: 0:07:49, time: 0.548, data_time: 0.041, memory: 3074, loss_rpn_cls: 0.0122, loss_rpn_bbox: 0.0522, loss_cls: 0.2302, acc: 90.2441, loss_bbox: 0.2994, loss: 0.5940
# 2025-03-01 11:25:10,532 - mmdet - INFO - Epoch [4][70/103]	lr: 2.500e-03, eta: 0:07:44, time: 0.542, data_time: 0.040, memory: 3074, loss_rpn_cls: 0.0131, loss_rpn_bbox: 0.0553, loss_cls: 0.2470, acc: 88.6914, loss_bbox: 0.2934, loss: 0.6088
# 2025-03-01 11:25:15,957 - mmdet - INFO - Epoch [4][80/103]	lr: 2.500e-03, eta: 0:07:38, time: 0.543, data_time: 0.042, memory: 3074, loss_rpn_cls: 0.0095, loss_rpn_bbox: 0.0454, loss_cls: 0.2273, acc: 90.0586, loss_bbox: 0.2854, loss: 0.5676
# 2025-03-01 11:25:21,361 - mmdet - INFO - Epoch [4][90/103]	lr: 2.500e-03, eta: 0:07:33, time: 0.540, data_time: 0.039, memory: 3074, loss_rpn_cls: 0.0108, loss_rpn_bbox: 0.0547, loss_cls: 0.2149, acc: 90.5957, loss_bbox: 0.3084, loss: 0.5888
# 2025-03-01 11:25:26,768 - mmdet - INFO - Epoch [4][100/103]	lr: 2.500e-03, eta: 0:07:27, time: 0.541, data_time: 0.040, memory: 3074, loss_rpn_cls: 0.0112, loss_rpn_bbox: 0.0505, loss_cls: 0.2392, acc: 89.3652, loss_bbox: 0.3182, loss: 0.6192
# 2025-03-01 11:25:35,808 - mmdet - INFO - Epoch [5][10/103]	lr: 2.500e-03, eta: 0:07:21, time: 0.734, data_time: 0.229, memory: 3074, loss_rpn_cls: 0.0118, loss_rpn_bbox: 0.0463, loss_cls: 0.2325, acc: 88.9746, loss_bbox: 0.2875, loss: 0.5781
# 2025-03-01 11:25:41,200 - mmdet - INFO - Epoch [5][20/103]	lr: 2.500e-03, eta: 0:07:16, time: 0.539, data_time: 0.041, memory: 3074, loss_rpn_cls: 0.0117, loss_rpn_bbox: 0.0489, loss_cls: 0.2242, acc: 89.8438, loss_bbox: 0.2787, loss: 0.5635
# 2025-03-01 11:25:46,586 - mmdet - INFO - Epoch [5][30/103]	lr: 2.500e-03, eta: 0:07:10, time: 0.538, data_time: 0.040, memory: 3074, loss_rpn_cls: 0.0095, loss_rpn_bbox: 0.0572, loss_cls: 0.2250, acc: 90.1367, loss_bbox: 0.3276, loss: 0.6193
# 2025-03-01 11:25:52,028 - mmdet - INFO - Epoch [5][40/103]	lr: 2.500e-03, eta: 0:07:05, time: 0.545, data_time: 0.042, memory: 3074, loss_rpn_cls: 0.0131, loss_rpn_bbox: 0.0484, loss_cls: 0.2233, acc: 89.8340, loss_bbox: 0.2803, loss: 0.5651
# 2025-03-01 11:25:57,451 - mmdet - INFO - Epoch [5][50/103]	lr: 2.500e-03, eta: 0:06:59, time: 0.542, data_time: 0.042, memory: 3074, loss_rpn_cls: 0.0111, loss_rpn_bbox: 0.0533, loss_cls: 0.2159, acc: 90.8887, loss_bbox: 0.2692, loss: 0.5495
# 2025-03-01 11:26:02,885 - mmdet - INFO - Epoch [5][60/103]	lr: 2.500e-03, eta: 0:06:54, time: 0.545, data_time: 0.043, memory: 3074, loss_rpn_cls: 0.0115, loss_rpn_bbox: 0.0406, loss_cls: 0.1877, acc: 91.8945, loss_bbox: 0.2593, loss: 0.4991
# 2025-03-01 11:26:08,305 - mmdet - INFO - Epoch [5][70/103]	lr: 2.500e-03, eta: 0:06:48, time: 0.541, data_time: 0.040, memory: 3074, loss_rpn_cls: 0.0118, loss_rpn_bbox: 0.0436, loss_cls: 0.2135, acc: 90.8691, loss_bbox: 0.2948, loss: 0.5637
# 2025-03-01 11:26:13,745 - mmdet - INFO - Epoch [5][80/103]	lr: 2.500e-03, eta: 0:06:43, time: 0.545, data_time: 0.041, memory: 3074, loss_rpn_cls: 0.0135, loss_rpn_bbox: 0.0457, loss_cls: 0.2042, acc: 90.8203, loss_bbox: 0.3034, loss: 0.5668
# 2025-03-01 11:26:19,227 - mmdet - INFO - Epoch [5][90/103]	lr: 2.500e-03, eta: 0:06:38, time: 0.547, data_time: 0.043, memory: 3074, loss_rpn_cls: 0.0137, loss_rpn_bbox: 0.0529, loss_cls: 0.2225, acc: 89.7266, loss_bbox: 0.3174, loss: 0.6065
# 2025-03-01 11:26:24,663 - mmdet - INFO - Epoch [5][100/103]	lr: 2.500e-03, eta: 0:06:32, time: 0.544, data_time: 0.039, memory: 3074, loss_rpn_cls: 0.0136, loss_rpn_bbox: 0.0551, loss_cls: 0.2196, acc: 90.1270, loss_bbox: 0.3182, loss: 0.6065
# 2025-03-01 11:26:33,749 - mmdet - INFO - Epoch [6][10/103]	lr: 2.500e-03, eta: 0:06:26, time: 0.734, data_time: 0.228, memory: 3074, loss_rpn_cls: 0.0075, loss_rpn_bbox: 0.0525, loss_cls: 0.2062, acc: 90.8398, loss_bbox: 0.2722, loss: 0.5384
# 2025-03-01 11:26:39,205 - mmdet - INFO - Epoch [6][20/103]	lr: 2.500e-03, eta: 0:06:20, time: 0.546, data_time: 0.040, memory: 3074, loss_rpn_cls: 0.0091, loss_rpn_bbox: 0.0411, loss_cls: 0.2080, acc: 90.7812, loss_bbox: 0.2599, loss: 0.5181
# 2025-03-01 11:26:44,596 - mmdet - INFO - Epoch [6][30/103]	lr: 2.500e-03, eta: 0:06:15, time: 0.539, data_time: 0.038, memory: 3074, loss_rpn_cls: 0.0092, loss_rpn_bbox: 0.0532, loss_cls: 0.1991, acc: 91.4746, loss_bbox: 0.3083, loss: 0.5698
# 2025-03-01 11:26:50,015 - mmdet - INFO - Epoch [6][40/103]	lr: 2.500e-03, eta: 0:06:09, time: 0.542, data_time: 0.041, memory: 3074, loss_rpn_cls: 0.0149, loss_rpn_bbox: 0.0434, loss_cls: 0.2231, acc: 90.2637, loss_bbox: 0.3064, loss: 0.5877
# 2025-03-01 11:26:55,434 - mmdet - INFO - Epoch [6][50/103]	lr: 2.500e-03, eta: 0:06:04, time: 0.541, data_time: 0.040, memory: 3074, loss_rpn_cls: 0.0097, loss_rpn_bbox: 0.0575, loss_cls: 0.2166, acc: 90.6934, loss_bbox: 0.3080, loss: 0.5918
# 2025-03-01 11:27:00,843 - mmdet - INFO - Epoch [6][60/103]	lr: 2.500e-03, eta: 0:05:58, time: 0.542, data_time: 0.039, memory: 3074, loss_rpn_cls: 0.0110, loss_rpn_bbox: 0.0441, loss_cls: 0.1861, acc: 91.8066, loss_bbox: 0.2697, loss: 0.5109
# 2025-03-01 11:27:06,300 - mmdet - INFO - Epoch [6][70/103]	lr: 2.500e-03, eta: 0:05:53, time: 0.545, data_time: 0.043, memory: 3074, loss_rpn_cls: 0.0110, loss_rpn_bbox: 0.0480, loss_cls: 0.2089, acc: 90.6543, loss_bbox: 0.2949, loss: 0.5628
# 2025-03-01 11:27:11,732 - mmdet - INFO - Epoch [6][80/103]	lr: 2.500e-03, eta: 0:05:48, time: 0.544, data_time: 0.041, memory: 3074, loss_rpn_cls: 0.0110, loss_rpn_bbox: 0.0453, loss_cls: 0.2310, acc: 89.8535, loss_bbox: 0.2769, loss: 0.5643
# 2025-03-01 11:27:17,209 - mmdet - INFO - Epoch [6][90/103]	lr: 2.500e-03, eta: 0:05:42, time: 0.547, data_time: 0.042, memory: 3074, loss_rpn_cls: 0.0106, loss_rpn_bbox: 0.0418, loss_cls: 0.2310, acc: 89.2480, loss_bbox: 0.2612, loss: 0.5446
# 2025-03-01 11:27:22,643 - mmdet - INFO - Epoch [6][100/103]	lr: 2.500e-03, eta: 0:05:37, time: 0.544, data_time: 0.041, memory: 3074, loss_rpn_cls: 0.0133, loss_rpn_bbox: 0.0515, loss_cls: 0.2284, acc: 89.7363, loss_bbox: 0.2893, loss: 0.5824
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-13149ed40afd> in <cell line: 0>()
#      15 # 모델 훈련
#      16 # epochs는 config의 runner 파라미터로 지정됨. 기본 12회
# ---> 17 train_detector(model, datasets, cfg, distributed=False, validate=True)
#
# /usr/local/lib/python3.11/dist-packages/mmdet-2.28.2-py3.11.egg/mmdet/apis/train.py in train_detector(model, dataset, cfg, distributed, validate, timestamp, meta)
#     244     elif cfg.load_from:
#     245         runner.load_checkpoint(cfg.load_from)
# --> 246     runner.run(data_loaders, cfg.workflow)
#
# /usr/local/lib/python3.11/dist-packages/mmcv/runner/epoch_based_runner.py in run(self, data_loaders, workflow, max_epochs, **kwargs)
#     134                     if mode == 'train' and self.epoch >= self._max_epochs:
#     135                         break
# --> 136                     epoch_runner(data_loaders[i], **kwargs)
#     137
#     138         time.sleep(1)  # wait for some hooks like loggers to finish
#
# /usr/local/lib/python3.11/dist-packages/mmcv/runner/epoch_based_runner.py in train(self, data_loader, **kwargs)
#      46         self._max_iters = self._max_epochs * len(self.data_loader)
#      47         self.call_hook('before_train_epoch')
# ---> 48         time.sleep(2)  # Prevent possible deadlock during epoch transition
#      49         for i, data_batch in enumerate(self.data_loader):
#      50             self.data_batch = data_batch
#
# KeyboardInterrupt:

# %%
# object detection 수행
import cv2
from mmdet.apis import inference_detector, init_detector, show_result_pyplot

img = cv2.imread('/content/BCCD_Dataset/BCCD/JPEGImages/BloodImage_00007.jpg')

model.cfg = cfg

result = inference_detector(model, img)
show_result_pyplot(model, img, result)
# Out:
# /usr/local/lib/python3.11/dist-packages/mmdet-2.28.2-py3.11.egg/mmdet/datasets/utils.py:66: UserWarning: "ImageToTensor" pipeline is replaced by "DefaultFormatBundle" for batch inference. It is recommended to manually replace it in the test data pipeline in your config file.
#   warnings.warn(

# %% [markdown]
# ### 테스트 데이터 세트에 Inference 및 Evaluation 적용하기
# * 런타임 다시 시작 수행 필요

# %%
### 아래는 런타임 다시 시작 후 실행
from mmcv import Config
from mmdet.datasets.builder import DATASETS
from mmdet.datasets.coco import CocoDataset
from mmdet.apis import set_random_seed

@DATASETS.register_module(force=True)
class BCCDDataset(CocoDataset):
  CLASSES = ('WBC', 'RBC', 'Platelets')

config_file = '/content/mmdetection/configs/faster_rcnn/faster_rcnn_r50_fpn_1x_coco.py'
checkpoint_file = '/content/mmdetection/checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth'

cfg = Config.fromfile(config_file)

# dataset에 대한 환경 파라미터 수정.
cfg.dataset_type = 'BCCDDataset'
cfg.data_root = '/content/BCCD_Dataset/BCCD/'

# train, val, test dataset에 대한 type, data_root, ann_file, img_prefix 환경 파라미터 수정.
cfg.data.train.type = 'BCCDDataset'
cfg.data.train.data_root = '/content/BCCD_Dataset/BCCD/'
cfg.data.train.ann_file = 'train.json'
cfg.data.train.img_prefix = 'JPEGImages'

cfg.data.val.type = 'BCCDDataset'
cfg.data.val.data_root = '/content/BCCD_Dataset/BCCD/'
cfg.data.val.ann_file = 'val.json'
cfg.data.val.img_prefix = 'JPEGImages'

cfg.data.test.type = 'BCCDDataset'
cfg.data.test.data_root = '/content/BCCD_Dataset/BCCD/'
cfg.data.test.ann_file = 'test.json'
cfg.data.test.img_prefix = 'JPEGImages'

# class의 갯수 수정.
cfg.model.roi_head.bbox_head.num_classes = 3
# pretrained 모델
cfg.load_from = '/content/mmdetection/checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth'

# 학습 weight 파일로 로그를 저장하기 위한 디렉토리 설정.
cfg.work_dir = './tutorial_exps'

# 학습율 변경 환경 파라미터 설정.
cfg.optimizer.lr = 0.02 / 8
cfg.lr_config.warmup = None
cfg.log_config.interval = 10

# CocoDataset의 경우 metric을 bbox로 설정해야 함.(mAP아님. bbox로 설정하면 mAP를 iou threshold를 0.5 ~ 0.95까지 변경하면서 측정)
cfg.evaluation.metric = 'bbox'
cfg.evaluation.interval = 12
cfg.checkpoint_config.interval = 12

# bug(?)로 인해 test용 dataset evaluation 시 1로 설정. data loader에서 GPU갯수별 Batch size 임.
cfg.data.samples_per_gpu = 1

# 두번 config를 로드하면 lr_config의 policy가 사라지는 오류로 인하여 설정.
cfg.lr_config.policy='step'
# Set seed thus the results are more reproducible
cfg.seed = 0
set_random_seed(0, deterministic=False)
cfg.gpu_ids = range(1)
print(cfg.pretty_text)
# Out:
# /usr/local/lib/python3.11/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/albumentations/__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.5' (you have '2.0.4'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# model = dict(
#     type='FasterRCNN',
#     backbone=dict(
#         type='ResNet',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=True,
#         style='pytorch',
#         init_cfg=dict(type='Pretrained', checkpoint='torchvision://resnet50')),
#     neck=dict(
#         type='FPN',
#         in_channels=[256, 512, 1024, 2048],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[8],
#             ratios=[0.5, 1.0, 2.0],
#             strides=[4, 8, 16, 32, 64]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[0.0, 0.0, 0.0, 0.0],
#             target_stds=[1.0, 1.0, 1.0, 1.0]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     roi_head=dict(
#         type='StandardRoIHead',
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[4, 8, 16, 32]),
#         bbox_head=dict(
#             type='Shared2FCBBoxHead',
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=3,
#             bbox_coder=dict(
#                 type='DeltaXYWHBBoxCoder',
#                 target_means=[0.0, 0.0, 0.0, 0.0],
#                 target_stds=[0.1, 0.1, 0.2, 0.2]),
#             reg_class_agnostic=False,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='L1Loss', loss_weight=1.0))),
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=-1,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.5,
#                 neg_iou_thr=0.5,
#                 min_pos_iou=0.5,
#                 match_low_quality=False,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             pos_weight=-1,
#             debug=False)),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=1000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=100)))
# dataset_type = 'BCCDDataset'
# data_root = '/content/BCCD_Dataset/BCCD/'
# img_norm_cfg = dict(
#     mean=[123.675, 116.28, 103.53], std=[58.395, 57.12, 57.375], to_rgb=True)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#     dict(type='RandomFlip', flip_ratio=0.5),
#     dict(
#         type='Normalize',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         to_rgb=True),
#     dict(type='Pad', size_divisor=32),
#     dict(type='DefaultFormatBundle'),
#     dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         type='MultiScaleFlipAug',
#         img_scale=(1333, 800),
#         flip=False,
#         transforms=[
#             dict(type='Resize', keep_ratio=True),
#             dict(type='RandomFlip'),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size_divisor=32),
#             dict(type='ImageToTensor', keys=['img']),
#             dict(type='Collect', keys=['img'])
#         ])
# ]
# data = dict(
#     samples_per_gpu=1,
#     workers_per_gpu=2,
#     train=dict(
#         type='BCCDDataset',
#         ann_file='train.json',
#         img_prefix='JPEGImages',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#             dict(type='RandomFlip', flip_ratio=0.5),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size_divisor=32),
#             dict(type='DefaultFormatBundle'),
#             dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
#         ],
#         data_root='/content/BCCD_Dataset/BCCD/'),
#     val=dict(
#         type='BCCDDataset',
#         ann_file='val.json',
#         img_prefix='JPEGImages',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ],
#         data_root='/content/BCCD_Dataset/BCCD/'),
#     test=dict(
#         type='BCCDDataset',
#         ann_file='test.json',
#         img_prefix='JPEGImages',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ],
#         data_root='/content/BCCD_Dataset/BCCD/'))
# evaluation = dict(interval=12, metric='bbox')
# optimizer = dict(type='SGD', lr=0.0025, momentum=0.9, weight_decay=0.0001)
# optimizer_config = dict(grad_clip=None)
# lr_config = dict(
#     policy='step',
#     warmup=None,
#     warmup_iters=500,
#     warmup_ratio=0.001,
#     step=[8, 11])
# runner = dict(type='EpochBasedRunner', max_epochs=12)
# checkpoint_config = dict(interval=12)
# log_config = dict(interval=10, hooks=[dict(type='TextLoggerHook')])
# custom_hooks = [dict(type='NumClassCheckHook')]
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# load_from = '/content/mmdetection/checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth'
# resume_from = None
# workflow = [('train', 1)]
# opencv_num_threads = 0
# mp_start_method = 'fork'
# auto_scale_lr = dict(enable=False, base_batch_size=16)
# work_dir = './tutorial_exps'
# seed = 0
# gpu_ids = range(0, 1)

# %%
# config 파일 저장.
cfg.dump('/content/tutorial_exps/bccd_faster_rcnn_conf.py')

# test 결과 저장 폴더 생성.
# !mkdir -p /content/show_test_output

# 테스트 실행
# %cd /content/mmdetection
# !python tools/test.py /content/tutorial_exps/bccd_faster_rcnn_conf.py /content/tutorial_exps/epoch_12.pth \
--eval 'bbox' \
--show-dir /content/show_test_output
# Out:
# /content/mmdetection
# /usr/local/lib/python3.11/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/albumentations/__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.5' (you have '2.0.4'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# /usr/local/lib/python3.11/dist-packages/mmdet-2.28.2-py3.11.egg/mmdet/utils/setup_env.py:38: UserWarning: Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/mmdet-2.28.2-py3.11.egg/mmdet/utils/setup_env.py:48: UserWarning: Setting MKL_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# Traceback (most recent call last):
#   File "/content/mmdetection/tools/test.py", line 286, in <module>
#     main()
#   File "/content/mmdetection/tools/test.py", line 217, in main
#     dataset = build_dataset(cfg.data.test)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mmdet-2.28.2-py3.11.egg/mmdet/datasets/builder.py", line 82, in build_dataset
#     dataset = build_from_cfg(cfg, DATASETS, default_args)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mmcv/utils/registry.py", line 61, in build_from_cfg
#     raise KeyError(
# KeyError: 'BCCDDataset is not in the dataset registry'

# %% [markdown]
# ### 테스트용 dataset와 dataloader를 별도로 설정하고 trained된 checkpoint 모델을 로딩하여 test 수행.

# %%
from mmdet.datasets import (build_dataloader, build_dataset,
                            replace_ImageToTensor)

# test용 Dataset과 DataLoader 생성.
# build_dataset()호출 시 list로 감싸지 않는 것이 train용 dataset 생성시와 차이.
dataset = build_dataset(cfg.data.test)
data_loader = build_dataloader(
        dataset,
        # 반드시 아래 samples_per_gpu 인자값은 1로 설정
        samples_per_gpu=cfg.data.samples_per_gpu,
        workers_per_gpu=cfg.data.workers_per_gpu,
        dist=False,
        shuffle=False)

# 반드시 아래 코드에서 'img' 키값이 tensor로 출력되어야 함.
next(iter(data_loader))
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# {'img_metas': [DataContainer([[{'filename': '/content/BCCD_Dataset/BCCD/JPEGImages/BloodImage_00007.jpg', 'ori_filename': 'BloodImage_00007.jpg', 'ori_shape': (480, 640, 3), 'img_shape': (800, 1067, 3), 'pad_shape': (800, 1088, 3), 'scale_factor': array([1.6671875, 1.6666666, 1.6671875, 1.6666666], dtype=float32), 'flip': False, 'flip_direction': None, 'img_norm_cfg': {'mean': array([123.675, 116.28 , 103.53 ], dtype=float32), 'std': array([58.395, 57.12 , 57.375], dtype=float32), 'to_rgb': True}}]])],
#  'img': [tensor([[[[0.9474, 0.9474, 0.9474,  ..., 0.0000, 0.0000, 0.0000],
#             [0.9474, 0.9474, 0.9474,  ..., 0.0000, 0.0000, 0.0000],
#             [0.9646, 0.9646, 0.9646,  ..., 0.0000, 0.0000, 0.0000],
#             ...,
#             [1.1700, 1.1700, 1.1700,  ..., 0.0000, 0.0000, 0.0000],
#             [1.1700, 1.1700, 1.1700,  ..., 0.0000, 0.0000, 0.0000],
#             [1.1700, 1.1700, 1.1700,  ..., 0.0000, 0.0000, 0.0000]],
#
#            [[1.2031, 1.2031, 1.2031,  ..., 0.0000, 0.0000, 0.0000],
#             [1.2031, 1.2031, 1.2031,  ..., 0.0000, 0.0000, 0.0000],
#             [1.2206, 1.2206, 1.2206,  ..., 0.0000, 0.0000, 0.0000],
#             ...,
#             [1.5007, 1.5007, 1.5007,  ..., 0.0000, 0.0000, 0.0000],
#             [1.5007, 1.5007, 1.5007,  ..., 0.0000, 0.0000, 0.0000],
#             [1.5007, 1.5007, 1.5007,  ..., 0.0000, 0.0000, 0.0000]],
#
#            [[1.3851, 1.3851, 1.3851,  ..., 0.0000, 0.0000, 0.0000],
#             [1.3851, 1.3851, 1.3851,  ..., 0.0000, 0.0000, 0.0000],
#             [1.4025, 1.3851, 1.3677,  ..., 0.0000, 0.0000, 0.0000],
#             ...,
#             [1.5768, 1.5768, 1.5768,  ..., 0.0000, 0.0000, 0.0000],
#             [1.5768, 1.5768, 1.5768,  ..., 0.0000, 0.0000, 0.0000],
#             [1.5768, 1.5768, 1.5768,  ..., 0.0000, 0.0000, 0.0000]]]])]}

# %%
from mmdet.apis import inference_detector, init_detector, show_result_pyplot

checkpoint_file = '/content/tutorial_exps/epoch_12.pth'

# checkpoint 저장된 model 파일을 이용하여 모델을 생성, 이때 Config는 위에서 update된 config 사용.
model_ckpt = init_detector(cfg, checkpoint_file, device='cuda:0')
# Out:
# load checkpoint from local path: /content/tutorial_exps/epoch_12.pth
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-0740d9e2aa15> in <cell line: 0>()
#       4
#       5 # checkpoint 저장된 model 파일을 이용하여 모델을 생성, 이때 Config는 위에서 update된 config 사용.
# ----> 6 model_ckpt = init_detector(cfg, checkpoint_file, device='cuda:0')
#
# /usr/local/lib/python3.11/dist-packages/mmdet-2.28.2-py3.11.egg/mmdet/apis/inference.py in init_detector(config, checkpoint, device, cfg_options)
#      44     model = build_detector(config.model, test_cfg=config.get('test_cfg'))
#      45     if checkpoint is not None:
# ---> 46         checkpoint = load_checkpoint(model, checkpoint, map_location='cpu')
#      47         if 'CLASSES' in checkpoint.get('meta', {}):
#      48             model.CLASSES = checkpoint['meta']['CLASSES']
#
# /usr/local/lib/python3.11/dist-packages/mmcv/runner/checkpoint.py in load_checkpoint(model, filename, map_location, strict, logger, revise_keys)
#     636         dict or OrderedDict: The loaded checkpoint.
#     637     """
# --> 638     checkpoint = _load_checkpoint(filename, map_location, logger)
#     639     # OrderedDict is a subclass of dict
#     640     if not isinstance(checkpoint, dict):
#
# /usr/local/lib/python3.11/dist-packages/mmcv/runner/checkpoint.py in _load_checkpoint(filename, map_location, logger)
#     570            information, which depends on the checkpoint.
#     571     """
# --> 572     return CheckpointLoader.load_checkpoint(filename, map_location, logger)
#     573
#     574
#
# /usr/local/lib/python3.11/dist-packages/mmcv/runner/checkpoint.py in load_checkpoint(cls, filename, map_location, logger)
#     312         mmcv.print_log(
#     313             f'load checkpoint from {class_name[10:]} path: {filename}', logger)
# --> 314         return checkpoint_loader(filename, map_location)  # type: ignore
#     315
#     316
#
# /usr/local/lib/python3.11/dist-packages/mmcv/runner/checkpoint.py in load_from_local(filename, map_location)
#     331     filename = osp.expanduser(filename)
#     332     if not osp.isfile(filename):
# --> 333         raise FileNotFoundError(f'{filename} can not be found.')
#     334     checkpoint = torch.load(filename, map_location=map_location)
#     335     return checkpoint
#
# FileNotFoundError: /content/tutorial_exps/epoch_12.pth can not be found.

# %%
from mmdet.apis import multi_gpu_test, single_gpu_test
from mmcv.parallel import MMDataParallel, MMDistributedDataParallel
from mmdet.apis import inference_detector, init_detector, show_result_pyplot

model_ckpt = MMDataParallel(model_ckpt, device_ids=[0])
# single_gpu_test() 를 호출하여 test데이터 세트의 interence 수행. 반드시 batch size는 1이 되어야 함.
# 위에서 만든 /content/show_test_output 디렉토리에 interence 결과가 시각화된 이미지가 저장됨.
outputs = single_gpu_test(model_ckpt, data_loader, True, '/content/show_test_output', 0.3)
# Out:
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 72/72, 4.6 task/s, elapsed: 16s, ETA:     0s
